# %%
medical_data = \
"""Marina Allison   ,27   ,   31.1 , 
#7010.0   ;Markus Valdez   ,   30, 
22.4,   #4050.0 ;Connie Ballard ,43 
,   25.3 , #12060.0 ;Darnell Weber   
,   35   , 20.6   , #7500.0;
Sylvie Charles   ,22, 22.1 
,#3022.0   ;   Vinay Padilla,24,   
26.9 ,#4620.0 ;Meredith Santiago, 51   , 
29.3 ,#16330.0;   Andre Mccarty, 
19,22.7 , #2900.0 ; 
Lorena Hodson ,65, 33.1 , #19370.0; 
Isaac Vu ,34, 24.8,   #7045.0"""

# Changing all '#' into '$' for insurance cost
updated_medical_data = medical_data.replace('#', '$')

# Creating a loop to count the medical records
num_records = 0
for character in updated_medical_data:
  if character == '$':
    num_records += 1
print('There are {num_records} medical records in the data.'.format(num_records=num_records))

# Splitting updated_medical_data into a list where every record is its own list
medical_data_split = updated_medical_data.split(';')
medical_records = []
for record in medical_data_split:
  split = record.split(',')
  medical_records.append(split)

# Getting rid of extra spacing in records for readability
medical_records_clean = []
for clean in medical_records:
  strip = [item.strip() for item in clean]
  medical_records_clean.append(strip)

# Printing the names of each individual
for record in medical_records_clean:
  print(record[0].upper())

# Creating new lists to store each records individual details
names = []
ages = []
bmis = []
insurance_costs = []
for name, age, bmi, cost in medical_records_clean:
  names.append(name)
  ages.append(age)
  bmis.append(bmi)
  insurance_costs.append(cost)

# Getting the average BMI
total_bmi = 0
for bmi in bmis:
  total_bmi += float(bmi)
average_bmi = total_bmi / len(bmis)
print('Average BMI: {average_bmi}'.format(average_bmi=average_bmi))

# Printing out each indivdual's record in a user friendly way
for n, a, b, c in medical_records_clean:
  print('{n} is {a} years old with a BMI of {b} and an insurance cost of {c}'.format(n=n, a=a, b=b, c=c))
# Out:
# There are 10 medical records in the data.
# MARINA ALLISON
# MARKUS VALDEZ
# CONNIE BALLARD
# DARNELL WEBER
# SYLVIE CHARLES
# VINAY PADILLA
# MEREDITH SANTIAGO
# ANDRE MCCARTY
# LORENA HODSON
# ISAAC VU
# Average BMI: 25.830000000000002
# Marina Allison is 27 years old with a BMI of 31.1 and an insurance cost of $7010.0
# Markus Valdez is 30 years old with a BMI of 22.4 and an insurance cost of $4050.0
# Connie Ballard is 43 years old with a BMI of 25.3 and an insurance cost of $12060.0
# Darnell Weber is 35 years old with a BMI of 20.6 and an insurance cost of $7500.0
# Sylvie Charles is 22 years old with a BMI of 22.1 and an insurance cost of $3022.0
# Vinay Padilla is 24 years old with a BMI of 26.9 and an insurance cost of $4620.0
# Meredith Santiago is 51 years old with a BMI of 29.3 and an insurance cost of $16330.0
# Andre Mccarty is 19 years old with a BMI of 22.7 and an insurance cost of $2900.0
# ...
